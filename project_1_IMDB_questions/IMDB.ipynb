# %%
import pandas as pd

data = pd.read_csv('data/movie_bd_v5.xls.txt')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# ...

# %%
data.head(3)
# Out:
#      imdb_id     budget     revenue      original_title  \
# 0  tt0369610  150000000  1513528810      Jurassic World
# 1  tt1392190  150000000   378436354  Mad Max: Fury Road
# 2  tt2908446  110000000   295238201           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#                       tagline  \
# 0           The park is open.
# 1          What a Lovely Day.
# 2  One Choice Can Destroy You
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
#                                       genres  \
# ...

# %% [markdown]
# ## Вопрос 1
#
# У какого фильма из списка самый большой бюджет?
#
# ### Варианты ответов
# - The Dark Knight Rises (tt1345836)
# - Spider-Man 3 (tt0413300)
# - Avengers: Age of Ultron (tt2395427)
# - The Warrior's Way (tt1032751)
# - Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
answers = ['tt1345836', 'tt0413300', 'tt2395427', 'tt1032751', 'tt1298650']

# %%
data[data['imdb_id'].isin(answers)]
# Out:
#         imdb_id     budget     revenue  \
# 14    tt2395427  280000000  1405035767
# 723   tt1298650  380000000  1021683000
# 972   tt1345836  250000000  1081041287
# 1676  tt0413300  258000000   890871626
#
#                                    original_title  \
# 14                        Avengers: Age of Ultron
# 723   Pirates of the Caribbean: On Stranger Tides
# 972                         The Dark Knight Rises
# 1676                                 Spider-Man 3
#
#                                                    cast           director  \
# 14    Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...        Joss Whedon
# 723   Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...       Rob Marshall
# 972   Christian Bale|Michael Caine|Gary Oldman|Anne ...  Christopher Nolan
# 1676  Tobey Maguire|Kirsten Dunst|James Franco|Thoma...          Sam Raimi
#
#                           tagline  \
# 14            A New Age Has Come.
# 723   Live Forever Or Die Trying.
# ...

# %%
data[data['imdb_id'].isin(answers)]\
    [data[data['imdb_id'].isin(answers)].revenue == data[data['imdb_id'].isin(answers)].revenue.max()]
# Out:
#       imdb_id     budget     revenue           original_title  \
# 14  tt2395427  280000000  1405035767  Avengers: Age of Ultron
#
#                                                  cast     director  \
# 14  Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...  Joss Whedon
#
#                 tagline                                           overview  \
# 14  A New Age Has Come.  When Tony Stark tries to jumpstart a dormant p...
#
#     runtime                            genres  \
# 14      141  Action|Adventure|Science Fiction
#
#                                  production_companies release_date  \
# 14  Marvel Studios|Prime Focus|Revolution Sun Studios    4/22/2015
#
#     vote_average  release_year
# 14           7.4          2015

# %% [markdown]
# ## Вопрос 2
#
# Какой из фильмов самый длительный (в минутах)?
#
# ### Варианты ответов
# - The Lord of the Rings: The Return of the King (tt0167260)
# - Gods and Generals (tt0167260)
# - King Kong (tt0360717)
# - Pearl Harbor (tt0213149)
# - Alexander (tt0346491)

# %%
answers = ['tt0167260', 'tt0167260', 'tt0360717', 'tt0213149', 'tt0346491']

# %%
data[data['imdb_id'].isin(answers)]\
    [data[data['imdb_id'].isin(answers)].runtime == data[data['imdb_id'].isin(answers)].runtime.max()]
# Out:
#         imdb_id    budget     revenue  \
# 1081  tt0167260  94000000  1118888979
#
#                                      original_title  \
# 1081  The Lord of the Rings: The Return of the King
#
#                                                    cast       director  \
# 1081  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...  Peter Jackson
#
#                               tagline  \
# 1081  The eye of the enemy is moving.
#
#                                                overview  runtime  \
# 1081  Aragorn is revealed as the heir to the ancient...      201
#
#                         genres           production_companies release_date  \
# 1081  Adventure|Fantasy|Action  WingNut Films|New Line Cinema    12/1/2003
#
#       vote_average  release_year
# 1081           7.9          2003

# %% [markdown]
# ## Вопрос 3
#
# Какой из фильмов самый короткий (в минутах)?
#
# ### Варианты ответов
# - Home on the Range tt0299172
# - The Jungle Book 2 tt0283426
# - Winnie the Pooh tt1449283
# - Corpse Bride tt0121164
# - Hoodwinked! tt0443536

# %%
answers = ['tt0299172', 'tt0283426', 'tt1449283', 'tt0121164', 'tt0443536']

# %%
data[data['imdb_id'].isin(answers)]\
    [data[data['imdb_id'].isin(answers)].runtime == data[data['imdb_id'].isin(answers)].runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %% [markdown]
# ## Вопрос 4
#
# Какое число ближе к средней длительности фильма в датасете?
#
# ### Варианты ответов
# - 115
# - 110
# - 105
# - 120
# - 100

# %%
answers = [115, 110, 105, 120, 100]

# %%
data_mean = data.runtime.mean()

# %%
result = answers[0]
for a in answers:
    if abs(result - data_mean) > abs(a - data_mean):
        result = a

# %%
result
# Out:
# 110

# %%
answers[[abs(x - data_mean) for x in answers].index(min([abs(x - data_mean) for x in answers]))]
# Out:
# 110

# %% [markdown]
# ## Вопрос 5
#
# Какое число ближе к медианной длительности фильма в датасете?
#
# ## Варианты ответов:
# - 106
# - 112
# - 101
# - 120
# - 115

# %%
answers = [106, 112, 101, 120, 115]

# %%
data_mediana = data.runtime.median()

# %%
answers[[abs(x - data_mediana) for x in answers].index(min([abs(x - data_mediana) for x in answers]))]
# Out:
# 106

# %% [markdown]
# ## Вопрос 6
#
# Какой самый прибыльный фильм?
# Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма.
#
# ## Варианты ответов:
# - The Avengers tt0848228
# - Minions tt2293640
# - Star Wars: The Force Awakens tt2488496
# - Furious 7 tt2820852
# - Avatar tt0499549

# %%
data[(data.revenue - data.budget)==(data.revenue - data.budget).min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year
# 1245           6.0          2013

# %%
answers = ['tt0848228', 'tt2293640', 'tt2488496', 'tt2820852', 'tt2820852']

# %%
data[data.imdb_id.isin(answers)]\
    [(data[data.imdb_id.isin(answers)].revenue - data[data.imdb_id.isin(answers)].budget)\
     ==(data[data.imdb_id.isin(answers)].revenue - data[data.imdb_id.isin(answers)].budget).min()]
# Out:
#      imdb_id    budget     revenue original_title  \
# 8  tt2293640  74000000  1156730962        Minions
#
#                                                 cast  \
# 8  Sandra Bullock|Jon Hamm|Michael Keaton|Allison...
#
#                    director                                       tagline  \
# 8  Kyle Balda|Pierre Coffin  Before Gru, they had a history of bad bosses
#
#                                             overview  runtime  \
# 8  Minions Stuart, Kevin and Bob are recruited by...       91
#
#                               genres  \
# 8  Family|Animation|Adventure|Comedy
#
#                             production_companies release_date  vote_average  \
# 8  Universal Pictures|Illumination Entertainment    6/17/2015           6.5
#
#    release_year
# 8          2015

# %% [markdown]
# ## Вопрос 7
#
#
# Какой фильм самый убыточный?
#
# ### Варианты ответов:
# - Supernova tt0134983
# - The Warrior's Way tt1032751
# - Flushed Away tt0424095
# - The Adventures of Pluto Nash tt0180052
# - The Lone Ranger tt1210819

# %%
answers = ['tt0134983', 'tt1032751', 'tt0424095', 'tt0180052', 'tt1210819']

# %%
data[(data.revenue - data.budget) == (data.revenue - data.budget).min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year
# 1245           6.0          2013

# %%
data[data.imdb_id.isin(answers)]
# Out:
#        imdb_id     budget     revenue               original_title  \
# 599  tt0468569  185000000  1001921825              The Dark Knight
# 601  tt0371746  140000000   585174222                     Iron Man
# 606  tt0441773  130000000   631744560                Kung Fu Panda
# 607  tt0795421   52000000   609841637                   Mamma Mia!
# 612  tt0479952  150000000   603900354  Madagascar: Escape 2 Africa
#
#                                                   cast  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...
# 601  Robert Downey Jr.|Terrence Howard|Jeff Bridges...
# 606  Jack Black|Dustin Hoffman|Angelina Jolie|Jacki...
# 607  Meryl Streep|Pierce Brosnan|Amanda Seyfried|Co...
# 612  Ben Stiller|Jada Pinkett Smith|David Schwimmer...
#
#                         director  \
# 599            Christopher Nolan
# 601                  Jon Favreau
# 606  Mark Osborne|John Stevenson
# 607               Phyllida Lloyd
# 612     Eric Darnell|Tom McGrath
#
# ...

# %%
data[data.imdb_id.isin(answers)]\
    [(data[data.imdb_id.isin(answers)].revenue - data[data.imdb_id.isin(answers)].budget)\
     == (data[data.imdb_id.isin(answers)].revenue - data[data.imdb_id.isin(answers)].budget).min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year
# 1245           6.0          2013

# %% [markdown]
# ## Вопрос 8
#
# У скольких фильмов из датасета объем сборов оказался выше бюджета?
#
# ### Варианты ответов:
# - 1478
# - 1520
# - 1241
# - 1135
# - 1398

# %%
len(data[data.revenue>data.budget])
# Out:
# 1478

# %% [markdown]
# ## Вопрос 9
#
# Какой фильм оказался самым кассовым в 2008 году?
#
# ### Варианты ответов:
# - Madagascar: Escape 2 Africa tt0479952
# - Iron Man tt0371746
# - Kung Fu Panda tt0441773
# - The Dark Knight tt0468569
# - Mamma Mia! tt0795421

# %%
answers = ['tt0479952', 'tt0371746', 'tt0441773', 'tt0468569', 'tt0795421']

# %%
data[data['imdb_id'].isin(answers)]\
    [data[data['imdb_id'].isin(answers)].revenue == data[data['imdb_id'].isin(answers)].revenue.max()]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year
# 599           8.1          2008

# %% [markdown]
# ## Вопрос 10
#
# Самый убыточный фильм за период с 2012 по 2014 гг. (включительно)?
#
# ### Варианты ответов:
# - Winter's Tale tt1837709
# - Stolen tt1656186
# - Broken City tt1235522
# - Upside Down tt1374992
# - The Lone Ranger tt1210819

# %%
data_years = data[(data['release_year']>2012) & (data['release_year']<2014)]

# %%
data_profit = data_years['budget']-data_years['revenue']

# %%
data_years[data_years['budget']-data_years['revenue'] == data_years['budget']-data_years['revenue'].min()].copy()
# Out:
#         imdb_id    budget  revenue  original_title  \
# 1290  tt2016940  25000000  2054941  Man of Tai Chi
#
#                                                    cast      director  \
# 1290  Keanu Reeves|Tiger Hu Chen|Jeremy Marinas|Stev...  Keanu Reeves
#
#                                  tagline  \
# 1290  No Rules. No Mercy. Pure Fighting.
#
#                                                overview  runtime  \
# 1290  In Beijing, a young martial artist's skill pla...      105
#
#             genres                               production_companies  \
# 1290  Action|Drama  Universal Pictures|Village Roadshow Pictures|C...
#
#      release_date  vote_average  release_year
# 1290     7/4/2013           5.6          2013

# %% [markdown]
# ## Вопрос 11
#
# Какого жанра фильмов больше всего?
#
# ### Варианты ответов:
# - Action
# - Adventure
# - Drama
# - Comedy
# - Thriller

# %%
qq
# Out:
#        imdb_id     budget     revenue               original_title  \
# 599  tt0468569  185000000  1001921825              The Dark Knight
# 601  tt0371746  140000000   585174222                     Iron Man
# 606  tt0441773  130000000   631744560                Kung Fu Panda
# 607  tt0795421   52000000   609841637                   Mamma Mia!
# 612  tt0479952  150000000   603900354  Madagascar: Escape 2 Africa
#
#                                                   cast  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...
# 601  Robert Downey Jr.|Terrence Howard|Jeff Bridges...
# 606  Jack Black|Dustin Hoffman|Angelina Jolie|Jacki...
# 607  Meryl Streep|Pierce Brosnan|Amanda Seyfried|Co...
# 612  Ben Stiller|Jada Pinkett Smith|David Schwimmer...
#
#                         director  \
# 599            Christopher Nolan
# 601                  Jon Favreau
# 606  Mark Osborne|John Stevenson
# 607               Phyllida Lloyd
# 612     Eric Darnell|Tom McGrath
#
# ...

# %% [markdown]
# получаем список уникальных жанров в переменную word

# %%
words = list(set([y for x in data.genres.str.split('|') for y in x]))

# %%
words
# Out:
# ['Adventure',
#  'History',
#  'Horror',
#  'Family',
#  'Western',
#  'Science Fiction',
#  'Music',
#  'War',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Foreign',
#  'Mystery',
#  'Action',
#  'Thriller',
#  'Fantasy',
#  'Romance',
#  'Drama',
#  'Animation']

# %% [markdown]
# дополняем датафрейм колнками с именем жанра и проставляем значение True если строка содердит даннй жанр

# %%
for word in words:
    data[word] = data['genres'].str.contains(word)

# %% [markdown]
# - преобразовываем True в 1 и False в NaN для суммирования
# - считаем общее количество жанров

# %%
import numpy as np
data.iloc[:,-19:-1].applymap(lambda x: 1 if x else np.nan).count()
# Out:
# Adventure          415
# History             62
# Horror             176
# Family             260
# Western             19
# Science Fiction    248
# Music               64
# War                 58
# Comedy             683
# Crime              315
# Documentary          8
# Foreign              2
# Mystery            168
# Action             582
# Thriller           596
# Fantasy            222
# Romance            308
# Drama              782
# dtype: int64

# %% [markdown]
# вычисляем жанр с максимальным кол-вом фильмов

# %%
data.iloc[:,-19:-1].applymap(lambda x: 1 if x else np.nan).count()\
    [data.iloc[:,-19:-1].applymap(lambda x: 1 if x else np.nan).count()==data.iloc[:,-19:-1].applymap(lambda x: 1 if x else np.nan).count().max()
                    ]
# Out:
# Drama    782
# dtype: int64
