# %%
import pandas as pd

# %%
rating = pd.read_csv('imbd/title.ratings.tsv', sep='\t')

# %%
rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1627
# 1  tt0000002            6.1       196
# 2  tt0000003            6.5      1317
# 3  tt0000004            6.2       119
# 4  tt0000005            6.1      2102

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054209 entries, 0 to 1054208
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1054209 non-null  object
#  1   averageRating  1054209 non-null  float64
#  2   numVotes       1054209 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 24.1+ MB

# %%
basics = pd.read_csv('imbd/name.basics.tsv', sep='\t')

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10226330 entries, 0 to 10226329
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 468.1+ MB

# %%
basics.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0043044,tt0072308,tt0053137
# 1  tt0071877,tt0117057,tt0037382,tt0038355
# 2  tt0049189,tt0059956,tt0057345,tt0054452
# 3  tt0072562,tt0080455,tt0078723,tt0077975
# 4  tt0060827,tt0050986,tt0050976,tt0083922

# %%
films = pd.read_csv('imbd/title.akas.tsv', sep='\t')
# Out:
# /Users/alexeyyarkov/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22340935 entries, 0 to 22340934
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 1.3+ GB

# %%
films.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
films[ (films['titleId']=='tt1345836')&(films['isOriginalTitle']=='1')]
# Out:
#            titleId  ordering                  title region language     types  \
# 8732265  tt1345836        26  The Dark Knight Rises     \N       \N  original
#
#         attributes isOriginalTitle
# 8732265         \N               1

# %% [markdown]
# ## обьеденим название с рейтингом

# %%
films_original = films[films['types']=='original']

# %%
films_original.sort_values('titleId')
# Out:
#             titleId  ordering                     title region language  \
# 6         tt0000001         7                Carmencita     \N       \N
# 8         tt0000002         1    Le clown et ses chiens     \N       \N
# 21        tt0000003         6            Pauvre Pierrot     \N       \N
# 25        tt0000004         1               Un bon bock     \N       \N
# 33        tt0000005        10          Blacksmith Scene     \N       \N
# ...             ...       ...                       ...    ...      ...
# 22340094  tt9916270         1  Il talento del calabrone     \N       \N
# 22340200  tt9916362         3                  Akelarre     \N       \N
# 22340324  tt9916460         2                 Pink Taxi     \N       \N
# 22340606  tt9916678         2                Acelerados     \N       \N
# 22340657  tt9916720         5                 The Nun 2     \N       \N
#
#              types attributes isOriginalTitle
# 6         original         \N               1
# ...

# %%
films_movie = films_original.merge(rating, how = 'left', left_on='titleId', right_on='tconst')

# %%
films_movie[films_movie['titleId']=='tt0000001']
# Out:
#      titleId  ordering       title region language     types attributes  \
# 0  tt0000001         7  Carmencita     \N       \N  original         \N
#
#   isOriginalTitle     tconst  averageRating  numVotes
# 0               1  tt0000001            5.6    1627.0

# %%
films_movie.head(15)
# Out:
#       titleId  ordering                                              title  \
# 0   tt0000001         7                                         Carmencita
# 1   tt0000002         1                             Le clown et ses chiens
# 2   tt0000003         6                                     Pauvre Pierrot
# 3   tt0000004         1                                        Un bon bock
# 4   tt0000005        10                                   Blacksmith Scene
# 5   tt0000006         5                                  Chinese Opium Den
# 6   tt0000007         2        Corbett and Courtney Before the Kinetograph
# 7   tt0000008         5             Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009         1                                         Miss Jerry
# 9   tt0000010         9                La sortie de l'usine Lumière à Lyon
# 10  tt0000011         2                            Akrobatisches Potpourri
# ...

# %%
films_movie = films_movie[films_movie['isOriginalTitle']=='1']

# %%
films_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373687 entries, 65543 to 18022320
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   titleId          373687 non-null  object
#  1   ordering         373687 non-null  int64
#  2   title            373687 non-null  object
#  3   region           373687 non-null  object
#  4   language         373687 non-null  object
#  5   types            373687 non-null  object
#  6   attributes       373687 non-null  object
#  7   isOriginalTitle  373687 non-null  object
#  8   tconst           236672 non-null  object
#  9   averageRating    236672 non-null  float64
#  10  numVotes         236672 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 34.2+ MB

# %%
films_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22340935 entries, 0 to 22340934
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
#  8   tconst           object
#  9   averageRating    float64
#  10  numVotes         float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.0+ GB

# %%
films_movie.sort_values('titleId')
# Out:
#             titleId  ordering                             title region  \
# 65543     tt0019471        13                   Three Week Ends     \N
# 65556     tt0019472         1                   3-Ring Marriage     \N
# 65560     tt0019473         1              Through the Breakers     \N
# 65568     tt0019474         6                    Thunder Riders     \N
# 65569     tt0019475         1                        Thundergod     \N
# ...             ...       ...                               ...    ...
# 18021686  tt7276948         2  Mahi-e siah-e koochooloo-ye dana     \N
# 18022113  tt7277116         3                    Moj va aramesh     \N
# 18022215  tt7277162         2       Star Trek: Starship Creator     \N
# 18022299  tt7277220         1  Koh-Lanta: La Revanche des héros     \N
# 18022320  tt7277230         4                          Totaled!     \N
#
#          language     types attributes isOriginalTitle     tconst  \
# ...

# %%
df = pd.read_csv('movie_bd_v5.xls.txt')

# %%
df.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# ...
