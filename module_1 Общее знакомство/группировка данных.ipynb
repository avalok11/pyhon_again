# %%
import pandas as pd

# %%
df = pd.read_csv('data_sf.csv.xls')

# %%
small_df = df[df.columns[1:8]].head(25)

# %%
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Poland       1
# England      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Poland       1
# England      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Argentina', 'Belgium', 'Uruguay', 'Germany', 'France',
#        'Portugal', 'Brazil', 'Croatia', 'Slovenia', 'Poland', 'England',
#        'Italy'],
#       dtype='object')

# %%
s.index[0]
# Out:
# 'Spain'

# %%
len(s.index)
# Out:
# 13

# %%
s['Germany']
# Out:
# 3

# %%
df.head(2)
# Out:
#    Unnamed: 0               Name  Age Nationality          Club      Value  \
# 0           0           L. Messi   31   Argentina  FC Barcelona  110500000
# 1           1  Cristiano Ronaldo   33    Portugal      Juventus   77000000
#
#      Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0  565000       RF        84         95  ...         75         96       33
# 1  405000       ST        84         94  ...         85         95       28
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 1              31             23         7          11         15
#
#    GKPositioning  GKReflexes
# 0             14           8
# 1             14          11
#
# [2 rows x 42 columns]

# %%
s.loc[s>1]
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Name: Nationality, dtype: int64

# %%
len(df['Club'].value_counts())
# Out:
# 650

# %%
df['Club'].value_counts().tail(9)
# Out:
# Club Brugge KV       9
# Olympiacos CFP       8
# Cruzeiro             8
# FC Metz              8
# Dijon FCO            8
# Vitória Guimarães    7
# GD Chaves            7
# Dinamo Zagreb        7
# Atlético Mineiro     6
# Name: Club, dtype: int64

# %%
s = small_df['Nationality'].value_counts(normalize=True)

# %%
display(s)
# Out:
# Spain        0.16
# Argentina    0.12
# Belgium      0.12
# Uruguay      0.12
# Germany      0.12
# France       0.08
# Portugal     0.04
# Brazil       0.04
# Croatia      0.04
# Slovenia     0.04
# Poland       0.04
# England      0.04
# Italy        0.04
# Name: Nationality, dtype: float64

# %%
q = df['Position'].value_counts(normalize=True)>0.1

# %%
q.loc[q==True]
# Out:
# GK    True
# ST    True
# CB    True
# Name: Position, dtype: bool

# %%
df['Position'].value_counts(normalize=True)<0.01
# Out:
# GK     False
# ST     False
# CB     False
# CM     False
# LB     False
# RB     False
# RM     False
# LM     False
# CDM    False
# CAM    False
# RCB    False
# LCB    False
# LW     False
# RCM    False
# RW     False
# LCM    False
# LDM    False
# RDM    False
# LS      True
# RS      True
# RWB     True
# LWB     True
# CF      True
# LF      True
# LAM     True
# RF      True
# RAM     True
# Name: Position, dtype: bool

# %%
s = small_df['Age'].value_counts()

# %%
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 33    2
# 29    2
# 24    2
# 25    1
# 28    1
# 30    1
# Name: Age, dtype: int64

# %%
s = small_df['Wage'].value_counts(bins=4)

# %%
s
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
s.index.left
# Out:
# Float64Index([211750.0, 93528.999, 329500.0, 447250.0], dtype='float64')

# %%
df['FKAccuracy'].value_counts(bins=5)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
s = small_df['Nationality'].value_counts()
print(s.index)
print(len(s.index))
# Out:
# Index(['Spain', 'Argentina', 'Belgium', 'Uruguay', 'Germany', 'France',
#        'Portugal', 'Brazil', 'Croatia', 'Slovenia', 'Poland', 'England',
#        'Italy'],
#       dtype='object')
# 13

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
small_df['Nationality'].nunique()
# Out:
# 13

# %%
small_df['Nationality'].value_counts()
# Out:
# Spain        4
# Argentina    3
# Belgium      3
# Uruguay      3
# Germany      3
# France       2
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Poland       1
# England      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
s = small_df['Nationality'].value_counts()

# %%
s_df = s.reset_index()
display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1   Argentina            3
# 2     Belgium            3
# 3     Uruguay            3
# 4     Germany            3
# 5      France            2
# 6    Portugal            1
# 7      Brazil            1
# 8     Croatia            1
# 9    Slovenia            1
# 10     Poland            1
# 11    England            1
# 12      Italy            1

# %%
s_df.columns=['Nationality', 'Players']

# %%
display(s_df)

## Задачи
# Out:
#    Nationality  Players
# 0        Spain        4
# 1    Argentina        3
# 2      Belgium        3
# 3      Uruguay        3
# 4      Germany        3
# 5       France        2
# 6     Portugal        1
# 7       Brazil        1
# 8      Croatia        1
# 9     Slovenia        1
# 10      Poland        1
# 11     England        1
# 12       Italy        1

# %%
df[df['Nationality']=='Spain']['Wage'].value_counts(bins=4, normalize=True)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
df[df['Club']=='Manchester United']['Nationality'].nunique()
# Out:
# 13

# %%
df[(df['Nationality']=='Brazil')&(df['Club']=='Juventus')]['Name'].unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
df[df['Age']>35][['Club','Name']].groupby(by='Club').count().sort_values(by='Name', ascending=False)
# Out:
#                              Name
# Club
# Club Atlético Huracán           4
# Hokkaido Consadole Sapporo      4
# Club Atlético Colón             3
# Gimnasia y Esgrima La Plata     3
# Club Atlético Talleres          3
# ...                           ...
# Girona FC                       1
# Grenoble Foot 38                1
# Grimsby Town                    1
# Guadalajara                     1
# Zagłębie Sosnowiec              1
#
# [212 rows x 1 columns]

# %%
ss = df[df['Nationality']=='Argentina']['Age'].value_counts(bins=4)

# %%
ss.index.left
# Out:
# Float64Index([22.25, 15.974, 28.5, 34.75], dtype='float64')

# %%
ss
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
df[df['Nationality']=='Spain']['Age'].value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 19    0.047690
# 29    0.047690
# 30    0.038748
# 18    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %% [markdown]
# ## GROUP BY

# %%
df.groupby(['Club'])

# %%
df.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
group_df = df.groupby(['Club']).sum()
display(group_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
group_df.loc['Ajax']
# Out:
# Unnamed: 0             26041
# Age                      275
# Value              152250000
# Wage                  158000
# Crossing                 844
# Finishing                723
# HeadingAccuracy          848
# ShortPassing             940
# Volleys                  696
# Dribbling                932
# Curve                    779
# FKAccuracy               680
# LongPassing              878
# BallControl              951
# Acceleration             944
# SprintSpeed              969
# Agility                  969
# Reactions                924
# Balance                  918
# ShotPower                876
# Jumping                  915
# Stamina                  974
# Strength                 896
# LongShots                720
# Aggression               847
# Interceptions            801
# Positioning              813
# Vision                   881
# Penalties                710
# Composure                929
# Marking                  750
# StandingTackle           814
# ...

# %%
group_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
group_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
display(group_df.head(3))
# Out:
# Club
# Real Madrid        4138000
# FC Barcelona       3967000
# Manchester City    3097000
# Name: Wage, dtype: int64

# %%
df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)>5000000
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# RCB    False
# LCB    False
# RW     False
# RCM    False
# LCM    False
# LW     False
# LS     False
# RDM    False
# RS     False
# LDM    False
# RF     False
# LF     False
# RWB    False
# LAM    False
# LWB    False
# CF     False
# RAM    False
# Name: Wage, dtype: bool

# %%
df.groupby(['Nationality'])[['Wage','Age', 'ShotPower']].mean().sort_values(['Wage'], ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
df.groupby(['Position'])[['Wage', 'Value']].mean().sort_values(['Value'], ascending=False).head(3)
# Out:
#               Wage         Value
# Position
# LF         75125.0  2.736250e+07
# RF        119000.0  2.636583e+07
# LAM        61000.0  1.324583e+07

# %%
s_df = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])

# %%
s_df[s_df['mean']==s_df['median']].count()
# Out:
# mean      52
# median    52
# dtype: int64

# %%
s_df[s_df['mean']==s_df['median']].sort_values(['mean'], ascending=False)
# Out:
#                            mean   median
# Club
# Cruzeiro                13000.0  13000.0
# Göztepe SK               7000.0   7000.0
# Brøndby IF               6000.0   6000.0
# Sunderland               4000.0   4000.0
# CD Feirense              4000.0   4000.0
# 1. FC Magdeburg          4000.0   4000.0
# Northampton Town         2500.0   2500.0
# Stade Brestois 29        2000.0   2000.0
# Jeonnam Dragons          2000.0   2000.0
# Pohang Steelers          2000.0   2000.0
# AJ Auxerre               2000.0   2000.0
# Grimsby Town             2000.0   2000.0
# Heracles Almelo          2000.0   2000.0
# Philadelphia Union       2000.0   2000.0
# Kashiwa Reysol           2000.0   2000.0
# CD Tondela               2000.0   2000.0
# Benevento                2000.0   2000.0
# FC Metz                  1500.0   1500.0
# PAOK                     1000.0   1000.0
# Orlando Pirates          1000.0   1000.0
# Panathinaikos FC         1000.0   1000.0
# Patriotas Boyacá FC      1000.0   1000.0
# ...

# %%
df[df['Club']=='Chelsea'].groupby(['Club'])['Wage'].sum()
# Out:
# Club
# Chelsea    2035000
# Name: Wage, dtype: int64

# %%
df[(df['Nationality']=='Argentina')&(df['Age']==30)]['Wage'].sort_values().head(3)
# Out:
# 6893    1000
# 3366    1000
# 4496    2000
# Name: Wage, dtype: int64

# %%
df[(df['Club']=='FC Barcelona')&(df['Nationality']=='Argentina')].groupby('Club')[['Strength','Balance']].max()
# Out:
#               Strength  Balance
# Club
# FC Barcelona        59       95

# %% [markdown]
# ## PIVOT TABLES

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
                                                                                                index=['Nationality'],
                                                                                                columns=['Club'],
                                                                                                aggfunc='sum')

# %%
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN
# Costa Rica                  NaN       NaN               NaN    195000.0
# Croatia                260000.0  160000.0               NaN    420000.0
# Dominican Republic          NaN       NaN               NaN    140000.0
# Ecuador                     NaN       NaN          120000.0         NaN
# England                     NaN       NaN          478000.0         NaN
# France                 495000.0  145000.0          375000.0    459000.0
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
                                                                                                index=['Nationality'],
                                                                                                columns=['Club'],
                                                                                                aggfunc='sum')

# %%
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN
# Costa Rica                  NaN       NaN               NaN    195000.0
# Croatia                260000.0  160000.0               NaN    420000.0
# Dominican Republic          NaN       NaN               NaN    140000.0
# Ecuador                     NaN       NaN          120000.0         NaN
# England                     NaN       NaN          478000.0         NaN
# France                 495000.0  145000.0          375000.0    459000.0
# ...

# %%
type(pivot)
# Out:
# pandas.core.frame.DataFrame

# %%
pivot.loc['Argentina']
# Out:
#       Club
# Wage  FC Barcelona         565000.0
#       Juventus             205000.0
#       Manchester United    206000.0
#       Real Madrid               NaN
# Name: Argentina, dtype: float64

# %%
pivot.loc['Argentina'][('Wage','Juventus')]
# Out:
# 205000.0

# %%
pivot2 = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage','Age'],
                                                                                                index=['Nationality'],
                                                                                                columns=['Club'],
                                                                                                aggfunc='sum')

# %%
display(pivot2.loc['Argentina'].index)
# Out:
# MultiIndex([( 'Age',      'FC Barcelona'),
#             ( 'Age',          'Juventus'),
#             ( 'Age', 'Manchester United'),
#             ( 'Age',       'Real Madrid'),
#             ('Wage',      'FC Barcelona'),
#             ('Wage',          'Juventus'),
#             ('Wage', 'Manchester United'),
#             ('Wage',       'Real Madrid')],
#            names=[None, 'Club'])

# %%
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')

values=['Wage'],index=['Nationality'],columns=['Club'],aggfunc='sum'

# %%
df2.loc['Manchester City']
# Out:
# Position
# CAM     36000.0
# CB     170000.0
# CDM    185000.0
# CF          NaN
# CM     175000.0
# GK     125000.0
# LAM         NaN
# LB     105000.0
# LCB    135000.0
# LCM    285000.0
# LDM         NaN
# LF          NaN
# LM          NaN
# LS          NaN
# LW     195000.0
# LWB         NaN
# RAM         NaN
# RB     110000.0
# RCB         NaN
# RCM    355000.0
# RDM         NaN
# RF          NaN
# RM       7000.0
# RS          NaN
# RW     205000.0
# RWB         NaN
# ST     300000.0
# Name: Manchester City, dtype: float64

# %%
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
display(df2)
# Out:
# Position                   CAM       CB      CDM      CF      CM       GK  \
# Club
#  SSV Jahn Regensburg       NaN   5000.0   5000.0     NaN  4000.0   5000.0
# 1. FC Heidenheim 1846   5000.0   7000.0      NaN     NaN  1000.0   4000.0
# 1. FC Kaiserslautern       NaN   1000.0   1000.0     NaN     NaN   1000.0
# 1. FC Köln                 NaN   1000.0  10000.0     NaN  3000.0  25000.0
# 1. FC Magdeburg            NaN   7000.0      NaN  4000.0     NaN   6000.0
# ...                        ...      ...      ...     ...     ...      ...
# Zagłębie Sosnowiec      2000.0   1000.0   1000.0     NaN     NaN   1000.0
# Çaykur Rizespor        11000.0  11000.0  13000.0     NaN     NaN   3000.0
# Örebro SK                  NaN   2000.0      NaN     NaN  1000.0   2000.0
# Östersunds FK           1000.0   1000.0      NaN  3000.0  8000.0   1000.0
# Śląsk Wrocław              NaN   1000.0   3000.0     NaN  1000.0   2000.0
#
# ...

# %%
pivot.loc['Belgium']
# Out:
#       Club
# Wage  FC Barcelona         110000.0
#       Juventus                  NaN
#       Manchester United    230000.0
#       Real Madrid          240000.0
# Name: Belgium, dtype: float64

# %%
pivot2 = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values='Wage',
        index=['Nationality'],
        columns=['Club'],
        aggfunc='sum',
        fill_value=0)

# %%
pivot2.loc['Belgium']
# Out:
# Club
# FC Barcelona         110000
# Juventus                  0
# Manchester United    230000
# Real Madrid          240000
# Name: Belgium, dtype: int64

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].
pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']['Name']['Juventus']
# Out:
# 1

# %%
q1 = df.pivot_table(values='Name', index='Club', columns='Position', aggfunc='count', fill_value=0, margins=True)

# %%
1641/650
# Out:
# 2.5246153846153847

# %%
q1.loc[:]['CM'].value_counts()
# Out:
# 1       211
# 2       149
# 0       136
# 3        89
# 4        39
# 5        21
# 6         5
# 1067      1
# Name: CM, dtype: int64

# %%
rus = df.pivot_table(values='Wage', index='Club', columns='Nationality', aggfunc='sum', fill_value=0)

# %%
rus.loc['AS Monaco']['Russia']
# Out:
# 61000

# %%
df.pivot_table(values='SprintSpeed', index='Position', columns='Club', aggfunc='mean', fill_value=0, margins=True).sort_values(['All'])
# Out:
# Club       SSV Jahn Regensburg  1. FC Heidenheim 1846  1. FC Kaiserslautern  \
# Position
# GK                   33.000000              41.000000             42.666667
# CB                   46.600000              61.333333             59.000000
# RCB                  57.000000              59.000000              0.000000
# LCB                   0.000000              55.000000             45.000000
# CDM                  82.000000               0.000000             65.666667
# LDM                  55.000000               0.000000              0.000000
# RDM                  65.000000               0.000000             55.000000
# All                  59.041667              65.450000             65.217391
# CM                   61.000000              68.000000              0.000000
# RCM                   0.000000               0.000000              0.000000
# LCM                   0.000000               0.000000              0.000000
# ...

# %%
df.pivot_table(values='SprintSpeed', index='Position', columns='Club', aggfunc='mean', fill_value=0, margins=True).sort_values(['All']).loc[['RM','RB','LM','CF','RS']]
# Out:
# Club       SSV Jahn Regensburg  1. FC Heidenheim 1846  1. FC Kaiserslautern  \
# Position
# RM                         0.0              78.333333                  82.5
# RB                        68.5              80.500000                  71.5
# LM                        76.0              69.500000                  70.5
# CF                         0.0               0.000000                   0.0
# RS                         0.0               0.000000                  69.0
#
# Club      1. FC Köln  1. FC Magdeburg  1. FC Nürnberg  1. FC Union Berlin  \
# Position
# RM              77.0             76.0            83.0                 0.0
# RB              70.0              0.0            75.0                86.0
# LM               0.0              0.0             0.0                 0.0
# CF               0.0             64.0             0.0                 0.0
# RS               0.0             53.0             0.0                 0.0
#
# ...
